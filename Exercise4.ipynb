# %% [markdown]
# <a href="https://colab.research.google.com/github/garapati-vikram-marthanda/week1/blob/main/Exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="AMARENDRA BAAHUBALI"
names=name.split()
print(names)
# Out:
# ['AMARENDRA', 'BAAHUBALI']

# %%
names2="-".join(names)
print(names2)
# Out:
# AMARENDRA-BAAHUBALI

# %%
names3="Vikram Marthanda"
print(names3.upper())
print(names3.lower())
x=names3.replace("Marthanda","Aditya")
print(x)
y="    Artificial Intelligence   "
print(y.strip())
print(names3.count('a'))
print(names3.find('t'))
# Out:
# VIKRAM MARTHANDA
# vikram marthanda
# Vikram Aditya
# Artificial Intelligence
# 4
# 10

# %%
#String Operations
str1="Artificial Intelligence and Data Science"
str2=" Machine learning"
print("Concatination : ",end="")
print(str1+str2)
print("Repetition: ",end="")
print(str2*2)
print("Indexing :",end="")
print("Element at Position 3(Index 2): ",str1[2])
print("Element at Position 3(Index 2) to Position 5(Index4): ",str2[2:5])
print("Slicing : ",end="")
print("Reverse Of Elements Using Slicing: ",str1[::-1])
print("Elements From The Last: ",str1[-4:-1])
print("Membership Operators: ",end="")
print("a" in str1)
print("Iterationns : ",end="")
for i in range(len(str1)):
   print(str1[i],end=" ")
# Out:
# Concatination : Artificial Intelligence and Data Science Machine learning
# Repetition:  Machine learning Machine learning
# Indexing :Element at Position 3(Index 2):  t
# Element at Position 3(Index 2) to Position 5(Index4):  ach
# Slicing : Reverse Of Elements Using Slicing:  ecneicS ataD dna ecnegilletnI laicifitrA
# Elements From The Last:  enc
# Membership Operators: True
# Iterationns : A r t i f i c i a l   I n t e l l i g e n c e   a n d   D a t a   S c i e n c e

# %%
#VOWEL COUNTER
sentence="Vikram marthanda"
sentence=sentence.lower()
count=0
for i in sentence:
  if(i in "aeiou"):
    count+=1

print(count)
# Out:
# 5

# %%
#substring is present in string or not.give the position
line="the sun rises in east"
substring="sun"
index=line.find(substring)
print(index)
# Out:
# 4

# %%
#Reverse Of Number
def reverse(num):
  sum=0
  while(num!=0):
    rem=num%10
    sum=sum*10+rem
    num=num//10
  return sum

number=int(input())
print(reverse(number))
# Out:
# 12345
# 54321
